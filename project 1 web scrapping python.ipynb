# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen 
import logging

# %%
flipkart_url="https://www.flipkart.com/search?q="+"weddingdress"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=weddingdress'

# %%
urlclient = urlopen(flipkart_url)

# %%
urlclient

# %%
flipkart_page=urlclient.read()

# %%
flipkart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.8f4f44.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipkart_html=bs(flipkart_page,'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
"http://www.flipkart.com/"+"/shankhpushpi-cotton-blend-embroidered-salwar-suit-material/p/itm4ac064a59f591?pid=FABGG6FGJAJ9JNQC&amp;lid=LSTFABGG6FGJAJ9JNQCCGVP1T&amp;marketplace=FLIPKART&amp;q=wedding+dress&amp;store=clo&amp;srno=s_1_3&amp;otracker=search&amp;otracker1=search&amp;fm=Search&amp;iid=a391c28e-d327-42b0-8c37-bf796df4604a.FABGG6FGJAJ9JNQC.SEARCH&amp;ppt=sp&amp;ppn=sp&amp;qH=e49f8641275c7a95"
# Out:
# 'http://www.flipkart.com//shankhpushpi-cotton-blend-embroidered-salwar-suit-material/p/itm4ac064a59f591?pid=FABGG6FGJAJ9JNQC&amp;lid=LSTFABGG6FGJAJ9JNQCCGVP1T&amp;marketplace=FLIPKART&amp;q=wedding+dress&amp;store=clo&amp;srno=s_1_3&amp;otracker=search&amp;otracker1=search&amp;fm=Search&amp;iid=a391c28e-d327-42b0-8c37-bf796df4604a.FABGG6FGJAJ9JNQC.SEARCH&amp;ppt=sp&amp;ppn=sp&amp;qH=e49f8641275c7a95'

# %%
bigbox = flipkart_html.findAll("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 15

# %%
del bigbox[0:3]

# %%
productlink='https://www.flipkart.com'+bigbox[3].div.div.div.a['href']
# Out:
# 'https://www.flipkart.com/mehzeel-fab-cotton-blend-dyed-embroidered-floral-print-kurta-churidar-material/p/itmbef1df13a9319?pid=FABGKKYHDUJWKNPN&lid=LSTFABGKKYHDUJWKNPNIWNHAW&marketplace=FLIPKART&q=weddingdress&store=clo&srno=s_1_21&otracker=search&fm=organic&iid=2912dc83-399d-490f-8cbc-6ed7702f9ab4.FABGKKYHDUJWKNPN.SEARCH&ppt=None&ppn=None&ssid=z5yccbbfeo0000001680310613412&qH=f0761c5bf1bc1d40'

# %%
product_req=requests.get(productlink)

# %%
productlink
# Out:
# 'https://www.flipkart.com/mehzeel-fab-cotton-blend-dyed-embroidered-floral-print-kurta-churidar-material/p/itmbef1df13a9319?pid=FABGKKYHDUJWKNPN&lid=LSTFABGKKYHDUJWKNPNIWNHAW&marketplace=FLIPKART&q=weddingdress&store=clo&srno=s_1_21&otracker=search&fm=organic&iid=2912dc83-399d-490f-8cbc-6ed7702f9ab4.FABGKKYHDUJWKNPN.SEARCH&ppt=None&ppn=None&ssid=z5yccbbfeo0000001680310613412&qH=f0761c5bf1bc1d40'

# %%
product_html = bs(product_req.text,'html.parser')

# %%
comment_box = product_html.find_all('div',{ 'class' : '_16PBlm _2RzJ9n'})

# %%
comment_box=product_html.find_all("div",{"class":"_16PBlm _2RzJ9n"})

# %%
len(comment_box)
# Out:
# 3

# %%
comment_box[0].div.div.find_all('p',{"class": "_2sc7ZR _2V5EHH _1QgsS5"})
# Out:
# [<p class="_2sc7ZR _2V5EHH _1QgsS5">Flipkart Customer</p>]

# %%
comment_box[0].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH _1QgsS5"})    ##for single name
# Out:
# [<p class="_2sc7ZR _2V5EHH _1QgsS5">Flipkart Customer</p>]

# %%
for i in comment_box:
    print(i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH _1QgsS5"})[0].text)  ## for all customer
# Out:
# Flipkart Customer
#
# sanjay dharmani

# %%
comment_box[0].div.div.div.div.div.div.div.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11460\3499364826.py in <module>
# ----> 1 comment_box[0].div.div.div.div.div.div.div.text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
for i in comment_box:
    print(i.div.div.div.div.div.div.text)
# Out:
# 5
# 3
# 3

# %%
for i in comment_box:
    print(i.div.div.div.text)
# Out:
# 5NiceREAD MORE
# 3This item is goodREAD MORE
# 3Superb fabric fast deliveryREAD MORE

# %%
comment_box[0].div.div.find_all('div',{"class":''})[0].div
# Out:
# <div class="_3LWZlK _1BLPMq _3B8WaH">5<img class="_1wB99o" src="..."/></div>

# %%
for i in comment_box:
    print(i.div.div.find_all('div',{"class":''})[0].div.text)
# Out:
# 5
# 3
# 3

# %%
for i in bigbox:
    print("https://www.flipkart.com"+ i.div.div.div.a["href"])
# Out:
# https://www.flipkart.com/veera-groups-georgette-embroidered-kurta-sharara-fabric/p/itm6cc493bf67d11?pid=FABGGCYZTFTDSDBS&lid=LSTFABGGCYZTFTDSDBSLBHDTT&marketplace=FLIPKART&q=weddingdress&store=clo&srno=s_1_9&otracker=search&fm=organic&iid=2912dc83-399d-490f-8cbc-6ed7702f9ab4.FABGGCYZTFTDSDBS.SEARCH&ppt=None&ppn=None&ssid=z5yccbbfeo0000001680310613412&qH=f0761c5bf1bc1d40
# https://www.flipkart.com/design-cut-cotton-blend-self-kurta-churidar-material/p/itm6fa45bda0ef67?pid=FABG62QX8NBTCFF2&lid=LSTFABG62QX8NBTCFF2RVIA7Y&marketplace=FLIPKART&q=weddingdress&store=clo&srno=s_1_13&otracker=search&fm=organic&iid=2912dc83-399d-490f-8cbc-6ed7702f9ab4.FABG62QX8NBTCFF2.SEARCH&ppt=None&ppn=None&ssid=z5yccbbfeo0000001680310613412&qH=f0761c5bf1bc1d40
# ...
